# %%
import pandas as pd
from pandas import DataFrame

import numpy as np
from datetime import datetime,date,time,timedelta
import pandasql as ps
from pandasql import sqldf

from basketball_reference_web_scraper import client
from basketball_reference_web_scraper.data import OutputType

# %% [markdown]
# https://stats.nba.com/team/1610612758/boxscores/
# https://www.basketball-reference.com/teams/SAC/2020.html
# https://github.com/jaebradley/basketball_reference_web_scraper

# %%
# Get all games for the 2019-2020 season
games20 = pd.DataFrame(client.season_schedule(season_end_year=2020))
games19 = pd.DataFrame(client.season_schedule(season_end_year=2019))
games18 = pd.DataFrame(client.season_schedule(season_end_year=2018))
games17 = pd.DataFrame(client.season_schedule(season_end_year=2017))
games16 = pd.DataFrame(client.season_schedule(season_end_year=2016))

games20.pop('start_time')
games20 = games20.dropna()
games20.head()
# Out:
#                    away_team  away_team_score                  home_team  \
# 0  Team.NEW_ORLEANS_PELICANS            122.0       Team.TORONTO_RAPTORS
# 1    Team.LOS_ANGELES_LAKERS            102.0  Team.LOS_ANGELES_CLIPPERS
# 2         Team.CHICAGO_BULLS            125.0     Team.CHARLOTTE_HORNETS
# 3       Team.DETROIT_PISTONS            119.0        Team.INDIANA_PACERS
# 4   Team.CLEVELAND_CAVALIERS             85.0         Team.ORLANDO_MAGIC
#
#    home_team_score
# 0            130.0
# 1            112.0
# 2            126.0
# 3            110.0
# 4             94.0

# %%
games20['away_team'] = games20['away_team'].astype(str)
games20['home_team'] = games20['home_team'].astype(str)

# %%
pysqldf = lambda q: sqldf(q,globals())
q = '''
    SELECT 
        * 
    FROM 
        games20 
    WHERE 
        away_team = 'Team.SACRAMENTO_KINGS' 
    OR
        home_team = 'Team.SACRAMENTO_KINGS'
    H;
    '''
kings = pysqldf(q)
kings
# Out:
#                       away_team  away_team_score                    home_team  \
# 0         Team.SACRAMENTO_KINGS             95.0            Team.PHOENIX_SUNS
# 1   Team.PORTLAND_TRAIL_BLAZERS            122.0        Team.SACRAMENTO_KINGS
# 2         Team.SACRAMENTO_KINGS             81.0               Team.UTAH_JAZZ
# 3           Team.DENVER_NUGGETS            101.0        Team.SACRAMENTO_KINGS
# 4        Team.CHARLOTTE_HORNETS            118.0        Team.SACRAMENTO_KINGS
# 5                Team.UTAH_JAZZ            101.0        Team.SACRAMENTO_KINGS
# 6         Team.SACRAMENTO_KINGS            113.0         Team.NEW_YORK_KNICKS
# 7         Team.SACRAMENTO_KINGS            120.0         Team.TORONTO_RAPTORS
# 8         Team.SACRAMENTO_KINGS            121.0           Team.ATLANTA_HAWKS
# 9   Team.PORTLAND_TRAIL_BLAZERS             99.0        Team.SACRAMENTO_KINGS
# 10        Team.SACRAMENTO_KINGS             97.0      Team.LOS_ANGELES_LAKERS
# 11          Team.BOSTON_CELTICS             99.0        Team.SACRAMENTO_KINGS
# 12            Team.PHOENIX_SUNS            116.0        Team.SACRAMENTO_KINGS
# 13        Team.SACRAMENTO_KINGS             97.0           Team.BROOKLYN_NETS
# 14        Team.SACRAMENTO_KINGS            113.0      Team.WASHINGTON_WIZARDS
# 15        Team.SACRAMENTO_KINGS            102.0          Team.BOSTON_CELTICS
# 16        Team.SACRAMENTO_KINGS             91.0      Team.PHILADELPHIA_76ERS
# 17          Team.DENVER_NUGGETS             97.0        Team.SACRAMENTO_KINGS
# 18           Team.CHICAGO_BULLS            113.0        Team.SACRAMENTO_KINGS
# 19        Team.SACRAMENTO_KINGS            116.0  Team.PORTLAND_TRAIL_BLAZERS
# 20        Team.SACRAMENTO_KINGS            104.0       Team.SAN_ANTONIO_SPURS
# 21        Team.SACRAMENTO_KINGS            110.0        Team.DALLAS_MAVERICKS
# 22        Team.SACRAMENTO_KINGS            119.0         Team.HOUSTON_ROCKETS
# 23   Team.OKLAHOMA_CITY_THUNDER             93.0        Team.SACRAMENTO_KINGS
# 24         Team.NEW_YORK_KNICKS            103.0        Team.SACRAMENTO_KINGS
# 25        Team.SACRAMENTO_KINGS            100.0   Team.GOLDEN_STATE_WARRIORS
# 26        Team.SACRAMENTO_KINGS            102.0       Team.CHARLOTTE_HORNETS
# 27        Team.SACRAMENTO_KINGS            105.0          Team.INDIANA_PACERS
# 28        Team.SACRAMENTO_KINGS            115.0       Team.MEMPHIS_GRIZZLIES
# 29         Team.HOUSTON_ROCKETS            113.0        Team.SACRAMENTO_KINGS
# 30  Team.MINNESOTA_TIMBERWOLVES            105.0        Team.SACRAMENTO_KINGS
# 31            Team.PHOENIX_SUNS            112.0        Team.SACRAMENTO_KINGS
# 32        Team.SACRAMENTO_KINGS            115.0          Team.DENVER_NUGGETS
# 33    Team.LOS_ANGELES_CLIPPERS            105.0        Team.SACRAMENTO_KINGS
# 34       Team.MEMPHIS_GRIZZLIES            123.0        Team.SACRAMENTO_KINGS
# 35    Team.NEW_ORLEANS_PELICANS            117.0        Team.SACRAMENTO_KINGS
# 36   Team.GOLDEN_STATE_WARRIORS             98.0        Team.SACRAMENTO_KINGS
# 37        Team.SACRAMENTO_KINGS            114.0            Team.PHOENIX_SUNS
# 38         Team.MILWAUKEE_BUCKS            127.0        Team.SACRAMENTO_KINGS
# 39           Team.ORLANDO_MAGIC            114.0        Team.SACRAMENTO_KINGS
# 40        Team.DALLAS_MAVERICKS            127.0        Team.SACRAMENTO_KINGS
# 41        Team.SACRAMENTO_KINGS            101.0               Team.UTAH_JAZZ
# 42        Team.SACRAMENTO_KINGS            113.0              Team.MIAMI_HEAT
# 43        Team.SACRAMENTO_KINGS            106.0         Team.DETROIT_PISTONS
# 44        Team.SACRAMENTO_KINGS             98.0           Team.CHICAGO_BULLS
# 45        Team.SACRAMENTO_KINGS            133.0  Team.MINNESOTA_TIMBERWOLVES
# 46   Team.OKLAHOMA_CITY_THUNDER            120.0        Team.SACRAMENTO_KINGS
# 47        Team.SACRAMENTO_KINGS            124.0    Team.LOS_ANGELES_CLIPPERS
# 48      Team.LOS_ANGELES_LAKERS            129.0        Team.SACRAMENTO_KINGS
# 49  Team.MINNESOTA_TIMBERWOLVES            109.0        Team.SACRAMENTO_KINGS
# 50              Team.MIAMI_HEAT             97.0        Team.SACRAMENTO_KINGS
# 51       Team.SAN_ANTONIO_SPURS            102.0        Team.SACRAMENTO_KINGS
# 52        Team.SACRAMENTO_KINGS            111.0         Team.MILWAUKEE_BUCKS
# 53        Team.SACRAMENTO_KINGS            111.0        Team.DALLAS_MAVERICKS
# 54       Team.MEMPHIS_GRIZZLIES            125.0        Team.SACRAMENTO_KINGS
#
#     home_team_score
# 0             124.0
# 1             112.0
# 2             113.0
# 3              94.0
# 4             111.0
# 5             102.0
# 6              92.0
# 7             124.0
# 8             109.0
# 9             107.0
# 10             99.0
# 11            100.0
# 12            120.0
# 13            116.0
# 14            106.0
# 15            103.0
# 16             97.0
# 17            100.0
# 18            106.0
# 19            127.0
# 20            105.0
# 21            106.0
# 22            118.0
# 23             94.0
# 24            101.0
# 25             79.0
# 26            110.0
# 27            119.0
# 28            119.0
# 29            104.0
# 30            104.0
# 31            110.0
# 32            120.0
# 33             87.0
# 34            128.0
# 35            115.0
# 36            111.0
# 37            103.0
# 38            106.0
# 39            112.0
# 40            123.0
# 41            123.0
# 42            118.0
# 43            127.0
# 44             81.0
# 45            129.0
# 46            100.0
# 47            103.0
# 48            113.0
# 49            113.0
# 50            105.0
# 51            122.0
# 52            123.0
# 53            130.0
# 54            129.0

# %% [markdown]
# ####
